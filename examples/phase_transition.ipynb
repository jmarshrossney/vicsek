# %%
import numpy as np
import matplotlib.pyplot as plt
from vicsek.model import VicsekModel
from vicsek.scripts.evolve_ensemble import evolve_ensemble

# %% [markdown]
# ## Instantiate the model

# %%
model = VicsekModel(
    length=500,
    density=0.01,
    speed=0.5,
    noise=0.5,
)
print(f"Number of particles: {model.agents}")
# Out:
# Number of particles: 2500

# %% [markdown]
# ## Run an animation

# %%
model.init_state()
model.animate(steps=200)

# %% [markdown]
# ## Look at typical 'thermalisation' times

# %%
evolve_ensemble(model, steps=100, ensemble_size=10, interactive=True)
# Out:
# Completed 0 simulations:   0%|          | 0/1000 [00:00<?, ?it/s]
# Continue? (y/n) > n

# %% [markdown]
# ## Plot the phase transition
